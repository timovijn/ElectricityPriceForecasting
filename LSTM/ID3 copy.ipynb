# %% [markdown]
# # Required packages

# %%
import numpy as np
import pandas as pd

from termcolor import colored

# %% [markdown]
# # Construct ID3

# %%
import os

frame = pd.DataFrame()
frame_small = pd.DataFrame()

for f in sorted(os.listdir('./ID3/')):

    if 'csv' in f:

        print(f)

        frame_small_comma = pd.read_csv(f'./ID3/{f}', sep = ",")
        frame_small_semi = pd.read_csv(f'./ID3/{f}', sep = ";")

        if frame_small_comma.shape[1] > frame_small_semi.shape[1]:
            frame_small = frame_small_comma
        else:
            frame_small = frame_small_semi
        
        frame_small = frame_small[(frame_small['IndexName'] == 'ID3') & (frame_small['TimeResolution'] == 'H')]

        frame_small = frame_small.set_index(pd.to_datetime(frame_small['DeliveryStart']))

        # frame_small.index = frame_small.index.replace(tzinfo = pytz.utc)

        # frame_small.index = frame_small.index.tz_localize('UTC')

        # frame_small.index = frame_small.index.tz_convert('UTC')

        frame = frame.append(frame_small)

        del frame_small

frame.index = pd.to_datetime(frame.index, utc = True)

frame.index = frame.index.tz_convert('UTC')
# Out:
# intraday_indices_netherlands_20200721.csv
# intraday_indices_netherlands_20200722.csv
# intraday_indices_netherlands_20200723.csv
# intraday_indices_netherlands_20200724.csv
# intraday_indices_netherlands_20200725.csv
# intraday_indices_netherlands_20200726.csv
# intraday_indices_netherlands_20200727.csv
# intraday_indices_netherlands_20200728.csv
# intraday_indices_netherlands_20200729.csv
# intraday_indices_netherlands_20200730.csv
# intraday_indices_netherlands_20200731.csv
# intraday_indices_netherlands_20200801.csv
# intraday_indices_netherlands_20200802.csv
# intraday_indices_netherlands_20200803.csv
# intraday_indices_netherlands_20200804.csv
# intraday_indices_netherlands_20200805.csv
# intraday_indices_netherlands_20200806.csv
# intraday_indices_netherlands_20200807.csv
# intraday_indices_netherlands_20200808.csv
# intraday_indices_netherlands_20200809.csv
# intraday_indices_netherlands_20200810.csv
# intraday_indices_netherlands_20200811.csv
# intraday_indices_netherlands_20200812.csv
# intraday_indices_netherlands_20200813.csv
# intraday_indices_netherlands_20200814.csv
# intraday_indices_netherlands_20200815.csv
# intraday_indices_netherlands_20200816.csv
# intraday_indices_netherlands_20200817.csv
# intraday_indices_netherlands_20200818.csv
# intraday_indices_netherlands_20200819.csv
# intraday_indices_netherlands_20200820.csv
# intraday_indices_netherlands_20200821.csv
# intraday_indices_netherlands_20200822.csv
# intraday_indices_netherlands_20200823.csv
# intraday_indices_netherlands_20200824.csv
# intraday_indices_netherlands_20200825.csv
# intraday_indices_netherlands_20200826.csv
# intraday_indices_netherlands_20200827.csv
# intraday_indices_netherlands_20200828.csv
# intraday_indices_netherlands_20200829.csv
# intraday_indices_netherlands_20200830.csv
# intraday_indices_netherlands_20200831.csv
# intraday_indices_netherlands_20200901.csv
# intraday_indices_netherlands_20200902.csv
# intraday_indices_netherlands_20200903.csv
# intraday_indices_netherlands_20200904.csv
# intraday_indices_netherlands_20200905.csv
# intraday_indices_netherlands_20200906.csv
# intraday_indices_netherlands_20200907.csv
# intraday_indices_netherlands_20200908.csv
# intraday_indices_netherlands_20200909.csv
# intraday_indices_netherlands_20200910.csv
# intraday_indices_netherlands_20210214.csv
# intraday_indices_netherlands_20210215.csv
# intraday_indices_netherlands_20210216.csv
# intraday_indices_netherlands_20210217.csv
# intraday_indices_netherlands_20210218.csv
# intraday_indices_netherlands_20210219.csv
# intraday_indices_netherlands_20210220.csv
# intraday_indices_netherlands_20210221.csv
# intraday_indices_netherlands_20210222.csv

# %%
display(frame)
# Out:
#                           Commodity NominationModality TradingModality  \
# DeliveryStart
# 2020-07-20 22:00:00+00:00     Power           Intraday      Continuous
# 2020-07-20 23:00:00+00:00     Power           Intraday      Continuous
# 2020-07-21 00:00:00+00:00     Power           Intraday      Continuous
# 2020-07-21 01:00:00+00:00     Power           Intraday      Continuous
# 2020-07-21 02:00:00+00:00     Power           Intraday      Continuous
# ...                             ...                ...             ...
# 2021-02-22 18:00:00+00:00     Power           Intraday      Continuous
# 2021-02-22 19:00:00+00:00     Power           Intraday      Continuous
# 2021-02-22 20:00:00+00:00     Power           Intraday      Continuous
# 2021-02-22 21:00:00+00:00     Power           Intraday      Continuous
# 2021-02-22 22:00:00+00:00     Power           Intraday      Continuous
#
#                           MarketArea IndexName TimeResolution  \
# DeliveryStart
# 2020-07-20 22:00:00+00:00         NL       ID3              H
# 2020-07-20 23:00:00+00:00         NL       ID3              H
# 2020-07-21 00:00:00+00:00         NL       ID3              H
# 2020-07-21 01:00:00+00:00         NL       ID3              H
# 2020-07-21 02:00:00+00:00         NL       ID3              H
# ...                              ...       ...            ...
# 2021-02-22 18:00:00+00:00         NL       ID3              H
# 2021-02-22 19:00:00+00:00         NL       ID3              H
# 2021-02-22 20:00:00+00:00         NL       ID3              H
# 2021-02-22 21:00:00+00:00         NL       ID3              H
# 2021-02-22 22:00:00+00:00         NL       ID3              H
#
#                                        DeliveryStart  \
# DeliveryStart
# 2020-07-20 22:00:00+00:00  2020-07-21T00:00:00+02:00
# 2020-07-20 23:00:00+00:00  2020-07-21T01:00:00+02:00
# 2020-07-21 00:00:00+00:00  2020-07-21T02:00:00+02:00
# 2020-07-21 01:00:00+00:00  2020-07-21T03:00:00+02:00
# 2020-07-21 02:00:00+00:00  2020-07-21T04:00:00+02:00
# ...                                              ...
# 2021-02-22 18:00:00+00:00  2021-02-22T19:00:00+01:00
# 2021-02-22 19:00:00+00:00  2021-02-22T20:00:00+01:00
# 2021-02-22 20:00:00+00:00  2021-02-22T21:00:00+01:00
# 2021-02-22 21:00:00+00:00  2021-02-22T22:00:00+01:00
# 2021-02-22 22:00:00+00:00  2021-02-22T23:00:00+01:00
#
#                                          DeliveryEnd  IndexPrice Currency  \
# DeliveryStart
# 2020-07-20 22:00:00+00:00  2020-07-21T01:00:00+02:00       31.84      EUR
# 2020-07-20 23:00:00+00:00  2020-07-21T02:00:00+02:00       30.47      EUR
# 2020-07-21 00:00:00+00:00  2020-07-21T03:00:00+02:00       28.73      EUR
# 2020-07-21 01:00:00+00:00  2020-07-21T04:00:00+02:00       27.78      EUR
# 2020-07-21 02:00:00+00:00  2020-07-21T05:00:00+02:00       28.01      EUR
# ...                                              ...         ...      ...
# 2021-02-22 18:00:00+00:00  2021-02-22T20:00:00+01:00       63.62      EUR
# 2021-02-22 19:00:00+00:00  2021-02-22T21:00:00+01:00       48.16      EUR
# 2021-02-22 20:00:00+00:00  2021-02-22T22:00:00+01:00       41.61      EUR
# 2021-02-22 21:00:00+00:00  2021-02-22T23:00:00+01:00       41.88      EUR
# 2021-02-22 22:00:00+00:00  2021-02-23T00:00:00+01:00       37.83      EUR
#
#                            Volume VolumeUnit
# DeliveryStart
# 2020-07-20 22:00:00+00:00   272.2        MWh
# 2020-07-20 23:00:00+00:00   334.7        MWh
# 2020-07-21 00:00:00+00:00   441.9        MWh
# 2020-07-21 01:00:00+00:00   331.3        MWh
# 2020-07-21 02:00:00+00:00    80.8        MWh
# ...                           ...        ...
# 2021-02-22 18:00:00+00:00   779.4        MWh
# 2021-02-22 19:00:00+00:00   870.1        MWh
# 2021-02-22 20:00:00+00:00   930.8        MWh
# 2021-02-22 21:00:00+00:00  1369.3        MWh
# 2021-02-22 22:00:00+00:00   803.2        MWh
#
# [5209 rows x 12 columns]

# %%
ID3 = pd.DataFrame(index = frame.index)

ID3.index.names = ['Timestamp']

ID3['ID3'] = frame['IndexPrice']

# %%
ID3.to_pickle('./ID3/ID3.pkl')

# %% [markdown]
# # Data processing

# %%
ID3['ID3'].plot();

# %% [markdown]
# # Create train and test set

# %%
def ts_train_test(ID3, time_steps, for_periods):

    # Create training and test sets
    mask = (ID3.index.year <= 2018)
    ts_train = ID3.loc[mask]['ID3'].values
    ts_train = ts_train.reshape(1, -1).transpose()

    mask = (ID3.index.year == 2019)
    ts_test = ID3.loc[mask]['ID3'].values
    ts_test = ts_test.reshape(1, -1).transpose()

    # ts_train = ID3[:'2018'].iloc['ID3'].values
    # ts_test  = ID3['2019':].iloc['ID3'].values

    # Scale the data
    from sklearn.preprocessing import MinMaxScaler
    sc = MinMaxScaler(feature_range=(0,1))
    ts_train_unscaled = ts_train
    ts_train = sc.fit_transform(ts_train)

    # Create training data of s samples and t time steps
    X_train = []
    y_train = []
    y_train_stacked = []
    
    for i in range(time_steps, len(ts_train)-1): 
        X_train.append(ts_train[i-time_steps:i,0])
        y_train.append(ts_train[i:i+for_periods,0])
    X_train, y_train = np.array(X_train), np.array(y_train)

    # Reshape X_train for efficient modelling
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

    # Prepare to create X_test
    inputs = pd.concat((ID3['ID3'][:'2018'], ID3['ID3']['2019':]),axis=0).values
    inputs = inputs[len(inputs)-len(ts_test) - time_steps:]
    inputs = inputs.reshape(-1,1)
    inputs  = sc.transform(inputs)

    X_test = []
    for i in range(time_steps, len(ts_test)+time_steps-for_periods):
        X_test.append(inputs[i-time_steps:i,0])
        
    X_test = np.array(X_test)
    X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

    return X_train, y_train , X_test, sc

##########################################################################
X_train, y_train, X_test, sc = ts_train_test(ID3, 5, 2)
##########################################################################

X_train.shape[0], X_train.shape[1]

print(X_train)

# %%
time_steps = 5
for_periods = 2

# Create training and test sets
mask = (ID3.index.year == 2018)
ts_train = ID3.loc[mask]['ID3'].values
ts_train = ts_train.reshape(1, -1).transpose()

mask = (ID3.index.year == 2019)
ts_test = ID3.loc[mask]['ID3'].values
ts_test = ts_test.reshape(1, -1).transpose()

# Scale the data
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))

ts_train_unscaled = ts_train
ts_train = sc.fit_transform(ts_train)

# Create training data of s samples and t time steps
X_train = []
y_train = []
y_train_stacked = []

for i in range(time_steps, len(ts_train)-1): 
    X_train.append(ts_train[i-time_steps:i,0])
    y_train.append(ts_train[i:i+for_periods,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshape X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# Prepare to create X_test
inputs = pd.concat((ID3['ID3'][:'2018'], ID3['ID3']['2019':]),axis=0).values
inputs = inputs[len(inputs)-len(ts_test) - time_steps:]
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

X_test = []
for i in range(time_steps, len(ts_test)+time_steps-for_periods):
    X_test.append(inputs[i-time_steps:i,0])
    
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

X_train.shape[0], X_train.shape[1]

print(X_train)

# %% [markdown]
# # Convert to printable

# %%
# Convert the 3-D shape of X_train to a data frame so we can see: 
X_train_see = pd.DataFrame(np.reshape(X_train, (X_train.shape[0], X_train.shape[1])))
y_train_see = pd.DataFrame(y_train)
pd.concat([X_train_see, y_train_see], axis=1)

# Convert the 3-D shape of X_test to a data frame so we can see: 
X_test_see = pd.DataFrame(np.reshape(X_test, (X_test.shape[0], X_test.shape[1])))
pd.DataFrame(X_test_see)

print(), print(colored(f'There are {X_train.shape[0]} samples in the training data', 'green'))
print(colored(f'There are {X_test.shape[0]} samples in the test data', 'green')), print()

print(X_train_see)
print(y_train_see)

# %% [markdown]
# # LSTM

# %%
def LSTM_model(X_train, y_train, X_test, sc):
    # create a model
    from keras.models import Sequential
    from keras.layers import Dense, SimpleRNN, GRU, LSTM
    from keras.optimizers import SGD, Adam
    
    model_lstm = Sequential()
    model_lstm.add(LSTM(units = 200, return_sequences = True, input_shape=(X_train.shape[1],1), activation='tanh'))
    model_lstm.add(LSTM(units = 100, return_sequences = True))
    model_lstm.add(LSTM(units = 50, return_sequences = False))
    
    model_lstm.add(Dense(units = 1, activation='linear'))

    optimizer = Adam(clipvalue=0.5)
    # model_lstm.compile(loss = 'mse', optimizer=optimizer)

    # Compiling
    model_lstm.compile(optimizer=optimizer,loss='mean_squared_error')
    # Fitting to the training set
    model_lstm.fit(X_train,y_train,epochs=50,batch_size=16, verbose=5)

    LSTM_prediction = model_lstm.predict(X_test)
    LSTM_prediction = sc.inverse_transform(LSTM_prediction)

    # self.model = model_lstm

    return model_lstm, LSTM_prediction

my_LSTM_model, LSTM_prediction = LSTM_model(X_train, y_train, X_test, sc)

# %%
def actual_pred_plot(preds):

    actual_pred = pd.DataFrame()

    mask = (ID3.index.year == 2019)
    actual_pred['Actual'] = ID3.loc[mask]['ID3'][0:len(preds)]
    actual_pred['Predicted'] = preds[:, 0]

    from keras.metrics import MeanSquaredError
    m = MeanSquaredError()
    actual_pred['Actual'] = actual_pred['Actual'].astype(int)
    actual_pred['Predicted'] = actual_pred['Predicted'].astype(int)
    m.update_state(np.array(actual_pred['Actual']), np.array(actual_pred['Predicted']))
    
    return (m.result().numpy(), actual_pred)

m, actual_pred = actual_pred_plot(LSTM_prediction)

# %%
def smape(a, f):
    return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))*100)

smape(actual_pred['Actual'], actual_pred['Predicted'])
