# %% [markdown]
# # Preamble

# %%
import os
os.system('clear')

import numpy as np
import pandas as pd
from datetime import datetime

from termcolor import colored
from SecretColors.palette import Palette
material = Palette("material", color_mode = 'hexa')

hex_salmon = '#F68F83'
hex_gold = '#BC9661'
hex_indigo = '#2D2E5F'
hex_maroon = '#8C4750'
hex_white = '#FAFAFA'
hex_blue = '#7EB5D2'

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.dates import DateFormatter
import matplotlib.dates as dates
mpl.rcParams['font.family'] = 'SF Compact Text'
mpl.rcParams['font.weight'] = 'medium'
mpl.rcParams['axes.titleweight'] = 'semibold'
mpl.rcParams['axes.labelweight'] = 'medium'
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=[hex_indigo, hex_salmon, hex_maroon])
mpl.rcParams["figure.titlesize"] = 'large'
mpl.rcParams["figure.titleweight"] = 'semibold'

print('')
print(colored('...','white'))
print('')
print(colored(f'Finished successfully', 'green'))
print('')
print(colored('...','white'))
print('')
# Out:
# ...
#
# Finished successfully
#
# ...

# %% [markdown]
# # Converting intraday (raw) data to intraday (pkl) for years before 2019

# %%
# RAW (ID)

flist = [f for f in sorted(os.listdir("./raw")) if not (f.startswith('.') or f.startswith('~'))]

print('')
print(colored('...','white'))
print('')
print(colored(f'Files in directory: {flist}', 'blue'))
print('')

# yyears = ['2015','2016','2017','2018']
yyears = ['2010', '2011', '2012', '2013', '2014', '2015','2016','2017','2018']

for filename in flist:
    y = filename[:4]
    if y in yyears:

        print(colored('...','white'))
        print('')
        print(colored(f'Currently processing file: {filename}', 'blue'))
        print(colored(f'Currently processing year: {y}', 'blue'))
        print('')
        
        df = pd.read_excel(f"./raw/{filename}", header = None)
        df = df.replace('Instrument code', 'Instrumentcode')
        df = df.replace('Contract type', 'Contracttype')
        df = df.dropna(how = 'all', axis = 0)
        df = df.dropna(how = 'all', axis = 1)
        df = df.reset_index(drop = True)
        
        df.columns = df.iloc[0]
        df = df.drop(0)

        df = df[~df['Instrumentcode'].str.contains('1H-25')]
        df = df[~df['Instrumentcode'].str.contains('1H 25')]

        df1 = df[~df['Instrumentcode'].str.contains('NL ID ')]
        df2 = df[df['Instrumentcode'].str.contains('NL ID ')]

        df1['Date'] = pd.to_datetime(df1['Instrumentcode'].str[:7], format = '%d%b%y')
        df2['Date'] = pd.to_datetime(df2['Instrumentcode'].str.replace("NL ID ", "").str[:7], format = '%y%b%d')
        df = pd.concat([df1, df2]).sort_index()

        df = df[df['Date'].dt.year == int(y)]

        df['Time'] = (df['Instrumentcode'].str[-2:].astype('int64') - 1).astype('str')
        df['Date'] = pd.to_datetime(df['Date'].dt.strftime("%Y-%m-%d") + ' ' + df['Time'].astype(str) + ':00:00')

        df['Price'] = df['Price'].astype('float')
        df['Volume'] = df['Volume'].astype('float')

        print(df)

        df.to_pickle(f"./{os.path.splitext(filename)[0]}.pkl")

print(colored('...','white'))
print('')
print(colored(f'Finished successfully', 'green'))
print('')
print(colored('...','white'))
print('')
# Out:
# ...
#
# Files in directory: ['2006_Intraday.xls', '2007_Intraday.xls', '2008_Intraday.xls', '2009_Intraday.xls', '2010_Intraday.xls', '2011_Intraday.xls', '2012_Intraday.xls', '2013_Intraday.xls', '2014_Intraday.xlsx', '2015_Intraday.xlsx', '2016_Intraday.xlsx', '2017_Intraday.xlsx', '2018_Intraday.xlsx', '2019', '2019_Intraday.xlsx', '2020']
#
# ...
#
# Currently processing file: 2010_Intraday.xls
# Currently processing year: 2010
#
# 0      Instrumentcode  Side  Volume  Price Contracttype  \
# 1     02JAN10 - 1H 19   buy    20.0   61.0         Spot
# 2     02JAN10 - 1H 20   buy    20.0   61.0         Spot
# 3     02JAN10 - 1H 21   buy    20.0   55.0         Spot
# 4     02JAN10 - 1H 22   buy    20.0   44.0         Spot
# 5     02JAN10 - 1H 23   buy    20.0   46.0         Spot
# ...               ...   ...     ...    ...          ...
# 2486  28DEC10 - 1H 21   buy    15.0   66.0         Spot
# 2487  28DEC10 - 1H 13  sell    15.0   72.0         Spot
# 2488  28DEC10 - 1H 14  sell    15.0   68.0         Spot
# 2489  28DEC10 - 1H 15  sell    15.0   64.0         Spot
# 2490  28DEC10 - 1H 21  sell    15.0   66.0         Spot
#
# 0    Creation timestamp (GMT)                Date Time
# 1         2010-01-02 10:22:43 2010-01-02 18:00:00   18
# 2         2010-01-02 10:22:46 2010-01-02 19:00:00   19
# 3         2010-01-02 12:21:52 2010-01-02 20:00:00   20
# 4         2010-01-02 10:21:36 2010-01-02 21:00:00   21
# 5         2010-01-02 10:21:39 2010-01-02 22:00:00   22
# ...                       ...                 ...  ...
# 2486      2010-12-28 13:48:43 2010-12-28 20:00:00   20
# 2487      2010-12-28 09:03:44 2010-12-28 12:00:00   12
# 2488      2010-12-28 09:03:46 2010-12-28 13:00:00   13
# 2489      2010-12-28 09:03:49 2010-12-28 14:00:00   14
# 2490      2010-12-28 13:48:43 2010-12-28 20:00:00   20
#
# [2490 rows x 8 columns]
# ...
#
# Currently processing file: 2011_Intraday.xls
# Currently processing year: 2011
#
# 0      Instrumentcode  Side  Volume  Price Contracttype  \
# 1     01JAN11 - 1H 15  sell    10.0   31.0         Spot
# 2     01JAN11 - 1H 16  sell    10.0   20.0         Spot
# 3     01JAN11 - 1H 17  sell    10.0   31.0         Spot
# 4     01JAN11 - 1H 18  sell    10.0   46.0         Spot
# 5     01JAN11 - 1H 19  sell    10.0   50.0         Spot
# ...               ...   ...     ...    ...          ...
# 6098  30DEC11 - 1H 03  sell   200.0   35.0         Spot
# 6099  30DEC11 - 1H 04  sell   200.0   35.0         Spot
# 6100  30DEC11 - 1H 05  sell   200.0   35.0         Spot
# 6101  30DEC11 - 1H 06  sell   200.0   35.0         Spot
# 6102  30DEC11 - 1H 07  sell   200.0   35.0         Spot
#
# 0    Creation timestamp (GMT)                Date Time
# 1         2011-01-01 11:00:51 2011-01-01 14:00:00   14
# 2         2011-01-01 11:00:51 2011-01-01 15:00:00   15
# 3         2011-01-01 11:00:51 2011-01-01 16:00:00   16
# 4         2011-01-01 11:00:51 2011-01-01 17:00:00   17
# 5         2011-01-01 11:00:51 2011-01-01 18:00:00   18
# ...                       ...                 ...  ...
# 6098      2011-12-29 20:22:22 2011-12-30 02:00:00    2
# 6099      2011-12-29 20:22:23 2011-12-30 03:00:00    3
# 6100      2011-12-29 20:22:24 2011-12-30 04:00:00    4
# 6101      2011-12-29 20:22:21 2011-12-30 05:00:00    5
# 6102      2011-12-29 20:22:21 2011-12-30 06:00:00    6
#
# [6102 rows x 8 columns]
# ...
#
# Currently processing file: 2012_Intraday.xls
# Currently processing year: 2012
#
# 0       Instrumentcode  Side  Volume  Price Contracttype  \
# 1      01JAN12 - 1H 07   buy     4.0    0.0         Spot
# 2      01JAN12 - 1H 07  sell     4.0    0.0         Spot
# 3      03JAN12 - 1H 24   buy    50.0   28.0         Spot
# 4      03JAN12 - 1H 24   buy    50.0   28.0         Spot
# 5      03JAN12 - 1H 24  sell    50.0   28.0         Spot
# ...                ...   ...     ...    ...          ...
# 16962  31DEC12 - 1H 06  sell    50.0   10.0         Spot
# 16963  31DEC12 - 1H 12   buy    10.0   45.0         Spot
# 16964  31DEC12 - 1H 10  sell    10.0   55.0         Spot
# 16965  31DEC12 - 1H 14  sell     5.0   60.0         Spot
# 16966  31DEC12 - 1H 15  sell    10.0   50.0         Spot
#
# 0     Creation timestamp (GMT)                Date Time
# 1          2011-12-31 19:41:58 2012-01-01 06:00:00    6
# 2          2011-12-31 19:41:58 2012-01-01 06:00:00    6
# 3          2012-01-03 17:51:50 2012-01-03 23:00:00   23
# 4          2012-01-03 17:51:50 2012-01-03 23:00:00   23
# 5          2012-01-03 17:51:50 2012-01-03 23:00:00   23
# ...                        ...                 ...  ...
# 16962      2012-12-31 01:31:33 2012-12-31 05:00:00    5
# 16963      2012-12-31 08:31:42 2012-12-31 11:00:00   11
# 16964      2012-12-31 07:41:37 2012-12-31 09:00:00    9
# 16965      2012-12-31 11:41:33 2012-12-31 13:00:00   13
# 16966      2012-12-31 12:51:33 2012-12-31 14:00:00   14
#
# [16966 rows x 8 columns]
# ...
#
# Currently processing file: 2013_Intraday.xls
# Currently processing year: 2013
#
# 0       Instrumentcode  Side  Volume  Price Contracttype  \
# 1      01JAN13 - 1H 01   buy    15.0   20.0         Spot
# 2      01JAN13 - 1H 02   buy    15.0   20.0         Spot
# 3      01JAN13 - 1H 03   buy    15.0   20.0         Spot
# 4      01JAN13 - 1H 01  sell    10.0   20.0         Spot
# 5      01JAN13 - 1H 01  sell    15.0   20.0         Spot
# ...                ...   ...     ...    ...          ...
# 43196  31DEC13 - 1H 24   buy     1.0   35.0         Spot
# 43197  31DEC13 - 1H 24   buy     5.0   30.0         Spot
# 43198  31DEC13 - 1H 24   buy     5.0   30.0         Spot
# 43199  31DEC13 - 1H 24   buy    15.0   34.0         Spot
# 43200  31DEC13 - 1H 24   buy    45.0   30.0         Spot
#
# 0     Creation timestamp (GMT)                Date Time
# 1          2012-12-31 19:51:44 2013-01-01 00:00:00    0
# 2          2012-12-31 19:51:44 2013-01-01 01:00:00    1
# 3          2012-12-31 19:51:44 2013-01-01 02:00:00    2
# 4          2012-12-31 19:51:44 2013-01-01 00:00:00    0
# 5          2012-12-31 19:51:44 2013-01-01 00:00:00    0
# ...                        ...                 ...  ...
# 43196      2013-12-31 20:22:35 2013-12-31 23:00:00   23
# 43197      2013-12-31 17:42:25 2013-12-31 23:00:00   23
# 43198      2013-12-31 18:32:25 2013-12-31 23:00:00   23
# 43199      2013-12-31 19:02:15 2013-12-31 23:00:00   23
# 43200      2013-12-31 19:12:25 2013-12-31 23:00:00   23
#
# [43200 rows x 8 columns]
# ...
#
# Currently processing file: 2014_Intraday.xlsx
# Currently processing year: 2014
#
# 0       Instrumentcode  Side  Volume  Price Contracttype  \
# 1      01JAN14 - 1H 04   buy    30.0   23.0         Spot
# 2      01JAN14 - 1H 04  sell    30.0   23.0         Spot
# 3      01JAN14 - 1H 01   buy    30.0   29.0         Spot
# 4      01JAN14 - 1H 01  sell    30.0   29.0         Spot
# 5      01JAN14 - 1H 02   buy    23.0   28.3         Spot
# ...                ...   ...     ...    ...          ...
# 68794  31DEC14 - 1H 12  sell    15.0   49.0         Spot
# 68795  31DEC14 - 1H 13  sell    21.0   48.0         Spot
# 68796  31DEC14 - 1H 14  sell    25.0   46.0         Spot
# 68797  31DEC14 - 1H 23  sell     5.0   30.0         Spot
# 68798  31DEC14 - 1H 24  sell    12.0   25.0         Spot
#
# 0     Creation timestamp (GMT)                Date Time
# 1          2013-12-31 20:42:45 2014-01-01 03:00:00    3
# 2          2013-12-31 20:42:45 2014-01-01 03:00:00    3
# 3          2013-12-31 20:42:45 2014-01-01 00:00:00    0
# 4          2013-12-31 20:42:45 2014-01-01 00:00:00    0
# 5          2013-12-31 20:42:47 2014-01-01 01:00:00    1
# ...                        ...                 ...  ...
# 68794      2014-12-31 09:22:25 2014-12-31 11:00:00   11
# 68795      2014-12-31 11:02:21 2014-12-31 12:00:00   12
# 68796      2014-12-31 11:42:28 2014-12-31 13:00:00   13
# 68797      2014-12-31 20:42:34 2014-12-31 22:00:00   22
# 68798      2014-12-31 20:42:34 2014-12-31 23:00:00   23
#
# [68788 rows x 8 columns]
# ...
#
# Currently processing file: 2015_Intraday.xlsx
# Currently processing year: 2015
#
# 0             Instrumentcode  Side  Price  Volume Contracttype  \
# 1            01JAN15 - 1H 01   buy   25.0     1.0         Spot
# 2            01JAN15 - 1H 01  sell   25.0     1.0         Spot
# 3            01JAN15 - 1H 01   buy   24.4     5.0         Spot
# 4            01JAN15 - 1H 01  sell   24.4     5.0         Spot
# 5            01JAN15 - 1H 01   buy   28.0     4.0         Spot
# ...                      ...   ...    ...     ...          ...
# 83352  NL ID 15DEC31 - 1H-22  sell   40.0     2.0         Spot
# 83353  NL ID 15DEC31 - 1H-23   buy   40.0     2.0         Spot
# 83354  NL ID 15DEC31 - 1H-23  sell   40.0     2.0         Spot
# 83355  NL ID 15DEC31 - 1H-22   buy   26.0    20.0         Spot
# 83356  NL ID 15DEC31 - 1H-22  sell   26.0    20.0         Spot
# 5       NL ID 17JAN01 - 1H-02  sell   45.0     0.1         Spot
# ...                       ...   ...    ...     ...          ...
# 359616        31DEC17 - 1H 24  sell   31.6     3.0  CrossBorder
# 359617  NL ID 17DEC31 - 1H-24   buy   22.0    15.0  CrossBorder
# 359618  NL ID 17DEC31 - 1H-24  sell   22.0    15.0         Spot
# 359619  NL ID 17DEC31 - 1H-24   buy   23.0    10.0  CrossBorder
# 359620  NL ID 17DEC31 - 1H-24  sell   23.0    10.0         Spot
#
# 0         Creation timestamp (GMT)                Date Time
# 1              2016-12-31 20:00:09 2017-01-01 00:00:00    0
# 2              2016-12-31 20:00:09 2017-01-01 00:00:00    0
# 3              2016-12-31 20:00:09 2017-01-01 01:00:00    1
# 4              2016-12-31 20:00:09 2017-01-01 01:00:00    1
# 5              2016-12-31 20:00:09 2017-01-01 01:00:00    1
# ...                            ...                 ...  ...
# 359616  2017-12-31 20:41:37.067000 2017-12-31 23:00:00   23
# 359617         2017-12-31 20:51:57 2017-12-31 23:00:00   23
# 359618         2017-12-31 20:51:57 2017-12-31 23:00:00   23
# 359619         2017-12-31 20:56:01 2017-12-31 23:00:00   23
# 359620         2017-12-31 20:56:01 2017-12-31 23:00:00   23
#
# [359608 rows x 8 columns]
# ...
#
# Currently processing file: 2018_Intraday.xlsx
# Currently processing year: 2018
#
# 0              Instrumentcode  Side  Price  Volume Contracttype  \
# 1       NL ID 18JAN01 - 1H-12   buy  29.95   159.0         Spot
# 2       NL ID 18JAN01 - 1H-12  sell  29.95   159.0  CrossBorder
# 3       NL ID 18JAN01 - 1H-13   buy  29.95    73.0         Spot
# 4       NL ID 18JAN01 - 1H-13  sell  29.95    73.0  CrossBorder
# 5       NL ID 18JAN01 - 1H-14   buy  34.95    13.0         Spot
# ...                       ...   ...    ...     ...          ...
# 817032  NL ID 18DEC31 - 1H-24  sell  40.00     0.3         Spot
# 817033  NL ID 18DEC31 - 1H-23   buy  50.00     0.3         Spot
# 817034  NL ID 18DEC31 - 1H-23  sell  50.00     0.3         Spot
# 817035  NL ID 18DEC31 - 1H-24   buy  49.00    20.0         Spot
# 817036  NL ID 18DEC31 - 1H-24  sell  49.00    20.0         Spot
#
# 0      Creation timestamp (GMT)                Date Time
# 1           2017-12-31 20:00:00 2018-01-01 11:00:00   11
# 2           2017-12-31 20:00:00 2018-01-01 11:00:00   11
# 3           2017-12-31 20:00:00 2018-01-01 12:00:00   12
# 4           2017-12-31 20:00:00 2018-01-01 12:00:00   12
# 5           2017-12-31 20:00:00 2018-01-01 13:00:00   13
# ...                         ...                 ...  ...
# 817032      2018-12-31 20:51:59 2018-12-31 23:00:00   23
# 817033      2018-12-31 20:54:23 2018-12-31 22:00:00   22
# 817034      2018-12-31 20:54:23 2018-12-31 22:00:00   22
# 817035      2018-12-31 21:09:18 2018-12-31 23:00:00   23
# 817036      2018-12-31 21:09:18 2018-12-31 23:00:00   23
#
# [817024 rows x 8 columns]
# ...
#
# Finished successfully
#
# ...

# %% [markdown]
# # Converting intraday (raw) data to intraday (pkl) for 2019

# %%
# RAW (ID)

flist = [f for f in sorted(os.listdir("./raw/2019")) if not (f.startswith('.') or f.startswith('~'))]

print('')
print(colored('...','white'))
print('')
print(colored(f'Files in directory: {flist}', 'blue'))
print('')

df3 = pd.DataFrame()

yyears = ['2019']

for filename in flist:
    y = filename[:4]
    m = filename[4:6]
    if y in yyears:

        print(colored('...','white'))
        print('')
        print(colored(f'Currently processing file: {filename}', 'blue'))
        print(colored(f'Currently processing year: {y}', 'blue'))
        print(colored(f'Currently processing month: {m}', 'blue'))
        print('')
        
        df = pd.read_excel(f"./raw/2019/{filename}", header = None)
        df = df.replace('Instrument code', 'Instrumentcode')
        df = df.replace('Contract type', 'Contracttype')
        df = df.dropna(how = 'all', axis = 0)
        df = df.dropna(how = 'all', axis = 1)
        df = df.reset_index(drop = True)
        
        df.columns = df.iloc[0]
        df = df.drop(0)

        df = df[~df['Instrumentcode'].str.contains('1H-25')]

        df1 = df[~df['Instrumentcode'].str.contains('NL ID ')]
        df2 = df[df['Instrumentcode'].str.contains('NL ID ')]

        df1['Date'] = pd.to_datetime(df1['Instrumentcode'].str[:7], format = '%d%b%y')
        df2['Date'] = pd.to_datetime(df2['Instrumentcode'].str.replace("NL ID ", "").str[:7], format = '%y%b%d')
        df = pd.concat([df1, df2]).sort_index()

        df = df[df['Date'].dt.year == int(y)]

        df['Time'] = (df['Instrumentcode'].str[-2:].astype('int64') - 1).astype('str')
        df['Date'] = pd.to_datetime(df['Date'].dt.strftime("%Y-%m-%d") + ' ' + df['Time'].astype(str) + ':00:00')

        df['Price'] = df['Price'].astype('float')
        df['Volume'] = df['Volume'].astype('float')

        df3 = pd.concat([df3, df])

df3.sort_values(by=['Date'])

df3.to_pickle(f"./{y}_Intraday.pkl")

print(colored('...','white'))
print('')
print(colored(f'Finished successfully', 'green'))
print('')
print(colored('...','white'))
print('')
# Out:
# ...
#
# Files in directory: ['201901_Intraday.xlsx', '201902_Intraday.xlsx', '201903_Intraday.xlsx', '201904_Intraday.xlsx', '201905_Intraday.xlsx', '201906_Intraday.xlsx', '201907_Intraday.xlsx', '201908_Intraday.xlsx', '201909_Intraday.xlsx', '201910_Intraday.xlsx', '201911_Intraday.xlsx']
#
# ...
#
# Currently processing file: 201901_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 01
#
# ...
#
# Currently processing file: 201902_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 02
#
# ...
#
# Currently processing file: 201903_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 03
#
# ...
#
# Currently processing file: 201904_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 04
#
# ...
#
# Currently processing file: 201905_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 05
#
# ...
#
# Currently processing file: 201906_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 06
#
# ...
#
# Currently processing file: 201907_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 07
#
# ...
#
# Currently processing file: 201908_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 08
#
# ...
#
# Currently processing file: 201909_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 09
#
# ...
#
# Currently processing file: 201910_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 10
#
# ...
#
# Currently processing file: 201911_Intraday.xlsx
# Currently processing year: 2019
# Currently processing month: 11
#
# ...
#
# Finished successfully
#
# ...

# %% [markdown]
# # Converting intraday (raw) data to intraday (pkl) for years after 2019

# %%
# RAW (ID)

flist = [f for f in sorted(os.listdir("./raw/2020")) if not (f.startswith('.') or f.startswith('~'))]

print('')
print(colored('...','white'))
print('')
print(colored(f'Files in directory: {flist}', 'blue'))
print('')

df2 = pd.DataFrame()

yyears = ['2020','2021']

for filename in flist:
    y = filename[21:25]
    m = filename[25:27]
    d = filename[27:29]
    if y in yyears:

        print(colored('...','white'))
        print('')
        print(colored(f'Currently processing file: {filename}', 'blue'))
        print(colored(f'Currently processing year: {y}', 'blue'))
        print(colored(f'Currently processing month: {m}', 'blue'))
        print(colored(f'Currently processing day: {d}', 'blue'))
        print('')
        
        df = pd.read_csv(f"./raw/2020/{filename}", header = None, decimal=',', thousands='.')

        df = df.dropna(how = 'all', axis = 0)
        df = df.dropna(how = 'all', axis = 1)
        df = df.reset_index(drop = True)
        
        df.columns = df.iloc[0]
        df = df.drop(0)

        # df = df[~df['Instrumentcode'].str.contains('1H-25')]

        # df1 = df[~df['Instrumentcode'].str.contains('NL ID ')]
        # df2 = df[df['Instrumentcode'].str.contains('NL ID ')]

        df['Date'] = pd.to_datetime(df['Delivery Start'].str[:-1], format = '%Y%m%dT%H%M%S')
        df['Creation timestamp (GMT)'] = pd.to_datetime(df['Execution time'].str[:-5], format = '%Y%m%dT%H%M%S')

        df = df[df['Date'].dt.year == int(y)]

        df['Price'] = df['Price'].astype('float')
        df['Volume'] = df['Quantity (MW)'].astype('float')

        df2 = pd.concat([df2, df])

df2.sort_values(by=['Date'])

for y in yyears:
    
    df2[df2['Date'].dt.year == int(y)].to_pickle(f"./{y}_Intraday.pkl")

print(colored('...','white'))
print('')
print(colored(f'Finished successfully', 'green'))
print('')
print(colored('...','white'))
print('')
# Out:
# th: 09
# Currently processing day: 11
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200912_20200912T224038Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 12
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200913_20200913T224316Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 13
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200914_20200914T224137Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 14
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200915_20200915T224545Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 15
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200916_20200916T224139Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 16
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200917_20200917T224130Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 17
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200918_20200918T223933Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 18
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200919_20200919T224046Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 19
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200920_20200920T223918Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 20
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200921_20200921T224027Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 21
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200922_20200922T224234Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 22
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200923_20200923T224235Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 23
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200924_20200924T224318Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 24
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200925_20200925T224140Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 25
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200926_20200926T224224Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 26
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200927_20200927T224139Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 27
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200928_20200928T224139Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 28
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200929_20200929T224233Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 29
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20200930_20201001T170211Z.csv
# Currently processing year: 2020
# Currently processing month: 09
# Currently processing day: 30
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201001_20201001T224434Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 01
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201002_20201002T224254Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 02
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201003_20201003T224539Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 03
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201004_20201004T224200Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 04
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201005_20201005T224120Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 05
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201006_20201006T224713Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 06
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201007_20201007T224247Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 07
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201008_20201008T224233Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 08
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201009_20201009T224023Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 09
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201010_20201010T224317Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 10
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201011_20201011T224420Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 11
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201012_20201012T224158Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 12
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201013_20201013T224218Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 13
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201014_20201014T224419Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 14
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201015_20201015T224425Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 15
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201016_20201016T224014Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 16
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201017_20201017T223847Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 17
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201018_20201018T224517Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 18
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201019_20201019T224345Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 19
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201020_20201020T224422Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 20
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201021_20201021T224207Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 21
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201022_20201022T224755Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 22
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201023_20201023T224338Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 23
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201024_20201024T223906Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 24
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201025_20201025T234129Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 25
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201026_20201026T234256Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 26
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201027_20201028T070736Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 27
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201028_20201028T234026Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 28
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201029_20201029T233851Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 29
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201030_20201030T234122Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 30
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201031_20201031T234101Z.csv
# Currently processing year: 2020
# Currently processing month: 10
# Currently processing day: 31
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201101_20201101T233910Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 01
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201102_20201102T233956Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 02
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201103_20201103T234231Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 03
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201104_20201104T234718Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 04
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201105_20201106T015836Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 05
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201106_20201107T023706Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 06
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201107_20201108T025254Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 07
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201108_20201109T025057Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 08
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201109_20201110T085136Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 09
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201110_20201110T234502Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 10
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201111_20201111T234529Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 11
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201112_20201112T235040Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 12
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201113_20201113T234427Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 13
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201114_20201114T234511Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 14
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201115_20201115T234751Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 15
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201116_20201116T234808Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 16
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201117_20201118T135947Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 17
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201118_20201118T234312Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 18
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201119_20201120T081236Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 19
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201120_20201120T234545Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 20
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201121_20201121T234503Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 21
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201122_20201122T234251Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 22
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201123_20201123T234505Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 23
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201124_20201124T234642Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 24
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201125_20201125T234430Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 25
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201126_20201126T234718Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 26
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201127_20201127T234426Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 27
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201128_20201128T234327Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 28
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201129_20201129T234247Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 29
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201130_20201130T234424Z.csv
# Currently processing year: 2020
# Currently processing month: 11
# Currently processing day: 30
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201201_20201201T234458Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 01
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201202_20201202T234546Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 02
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201203_20201203T234701Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 03
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201204_20201204T234450Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 04
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201205_20201205T234630Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 05
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201206_20201206T234137Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 06
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201207_20201207T234837Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 07
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201208_20201208T234440Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 08
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201209_20201210T091733Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 09
#
# ...
#
# Currently processing file: Continuous_Trades_NL_20201210_20201210T234252Z.csv
# Currently processing year: 2020
# Currently processing month: 12
# Currently processing day: 10
#
# ...
#
# Finished successfully
#
# ...

# %%
years = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %% [markdown]
# # Convert intraday (pkl) to intraday (df)

# %%
# INTRADAY (ID)

dfo = pd.DataFrame()
dfo_group = pd.DataFrame()
dfo_group2 = pd.DataFrame()
dfo_group3 = pd.DataFrame()

price = []
volume = []
breaks = []

for y in years:

    i = years.index(y)

    if int(y) >= 2020:

        df = pd.read_pickle(f"./{y}_Intraday.pkl")
        
        volume_buy = df.loc[df['Side'] == 'BUY', 'Volume'].sum()
        volume_sell = df.loc[df['Side'] == 'SELL', 'Volume'].sum()

        price_buy = df.loc[df['Side'] == 'BUY', 'Price'].sum()
        price_sell = df.loc[df['Side'] == 'SELL', 'Price'].sum()

        # df = df[df['Side'].str.contains('BUY')]

        df_group = df.drop(['Product', 'Delivery Start', 'Delivery End', 'isOTC', 'Execution time', 'Side', 'Market area', 'is Half Trade', 'Is Self Trade', 'Currency', 'Quantity (MW)'], axis=1).groupby([(df['Date'].dt.year),(df['Date'].dt.month)]).sum()
        df_group['Date'] = df_group.index
        df_group['Date'] = pd.to_datetime(df_group['Date'], format='(%Y, %m)')

        df_group2 = df.drop(['Product', 'Delivery Start', 'Delivery End', 'isOTC', 'Execution time', 'Side', 'Market area', 'is Half Trade', 'Is Self Trade', 'Currency', 'Quantity (MW)'], axis=1).groupby([(df['Date'].dt.year), (df['Date'].dt.month), (df['Date'].dt.day)]).mean()
        df_group2['Date'] = df_group2.index
        df_group2['Date'] = pd.to_datetime(df_group2['Date'], format='(%Y, %m, %d)')

        df_group3 = df.drop(['Product', 'Delivery Start', 'Delivery End', 'isOTC', 'Execution time', 'Side', 'Market area', 'is Half Trade', 'Is Self Trade', 'Currency', 'Quantity (MW)'], axis=1).groupby([(df['Date'].dt.year), (df['Date'].dt.month), (df['Date'].dt.day), (df['Date'].dt.hour)]).mean()
        df_group3['Date'] = df_group3.index
        df_group3['Date'] = pd.to_datetime(df_group3['Date'], format='(%Y, %m, %d, %H)')

        df_group = df_group.set_index(pd.DatetimeIndex(df_group['Date']))
        df_group2 = df_group2.set_index(pd.DatetimeIndex(df_group2['Date']))
        df_group3 = df_group3.set_index(pd.DatetimeIndex(df_group3['Date']))

    else:

        df = pd.read_pickle(f"./{y}_Intraday.pkl")
        
        print(df)

        # df['Price'] = df['Price'].astype('float')
        # df['Volume'] = df['Volume'].astype('float')
        # print(df['Price'])
        # print(df['Volume'])

        df['Creation timestamp (GMT)'] = pd.to_datetime(df['Creation timestamp (GMT)'], format='%d-%m-%Y %H:%M:%S')

        # volume_buy = df.loc[df['Contracttype'] == 'Spot'].loc[df['Side'] == 'buy', 'Volume'].sum()
        # volume_sell = df.loc[df['Contracttype'] == 'Spot'].loc[df['Side'] == 'sell', 'Volume'].sum()

        # price_buy = df.loc[df['Contracttype'] == 'Spot'].loc[df['Side'] == 'buy', 'Price'].sum()
        # price_sell = df.loc[df['Contracttype'] == 'Spot'].loc[df['Side'] == 'sell', 'Price'].sum()

        df = df[df['Side'].str.contains('buy')]

        df_group = df.drop(['Instrumentcode', 'Contracttype', 'Side'], axis=1).groupby([(df['Date'].dt.year),(df['Date'].dt.month)]).sum()
        df_group['Date'] = df_group.index
        df_group['Date'] = pd.to_datetime(df_group['Date'], format='(%Y, %m)')

        df_group2 = df.drop(['Instrumentcode', 'Contracttype', 'Side'], axis=1).groupby([(df['Date'].dt.year), (df['Date'].dt.month), (df['Date'].dt.day)]).mean()
        df_group2['Date'] = df_group2.index
        df_group2['Date'] = pd.to_datetime(df_group2['Date'], format='(%Y, %m, %d)')

        df_group3 = df.drop(['Instrumentcode', 'Contracttype', 'Side'], axis=1).groupby([(df['Date'].dt.year), (df['Date'].dt.month), (df['Date'].dt.day), (df['Date'].dt.hour)]).mean()
        df_group3['Date'] = df_group3.index
        df_group3['Date'] = pd.to_datetime(df_group3['Date'], format='(%Y, %m, %d, %H)')

        df_group = df_group.set_index(pd.DatetimeIndex(df_group['Date']))
        df_group2 = df_group2.set_index(pd.DatetimeIndex(df_group2['Date']))
        df_group3 = df_group3.set_index(pd.DatetimeIndex(df_group3['Date']))

    dfo = dfo.append(df, ignore_index = False)
    dfo_group = dfo_group.append(df_group, ignore_index = False)
    dfo_group2 = dfo_group2.append(df_group2, ignore_index = False)
    dfo_group3 = dfo_group3.append(df_group3, ignore_index = False)

    price.append(df['Price'].sum())
    volume.append(df['Volume'].sum())
    
    print('')
    print(colored('...','white'))
    print('')
    print(colored(f'Year: {y}', 'blue'))
    print('')
    print(colored(f'Price: {int(round(price[i]))} Euro', 'blue'))
    print(colored(f'Volume: {int(round(volume[i]))} MWh', 'blue'))
    
print('')
print(colored('...','white'))
print('')
print(colored(f'Period: {years[0]}–{years[-1]}', 'blue'))
print('')
print(colored(f'Price (sum): {int(round(sum(price)))} Euro', 'blue'))
print(colored(f'Volume (sum): {int(round(sum(volume)))} MWh', 'blue'))
print('')

dfo['Time to delivery'] = dfo['Date'] - dfo['Creation timestamp (GMT)']
dfo['Time to delivery'] = dfo['Time to delivery'] / np.timedelta64(1, 'h')
# df['Time to delivery'] = (df['Date'] - df['Creation timestamp (GMT)']).astype('timedelta64[h]')

print(colored('...','white'))
print('')
print(colored(f'Finished successfully', 'green'))
print('')
print(colored('...','white'))
print('')
# Out:
# 0      Instrumentcode  Side  Volume  Price Contracttype  \
# 1     02JAN10 - 1H 19   buy    20.0   61.0         Spot
# 2     02JAN10 - 1H 20   buy    20.0   61.0         Spot
# 3     02JAN10 - 1H 21   buy    20.0   55.0         Spot
# 4     02JAN10 - 1H 22   buy    20.0   44.0         Spot
# 5     02JAN10 - 1H 23   buy    20.0   46.0         Spot
# ...               ...   ...     ...    ...          ...
# 2486  28DEC10 - 1H 21   buy    15.0   66.0         Spot
# 2487  28DEC10 - 1H 13  sell    15.0   72.0         Spot
# 2488  28DEC10 - 1H 14  sell    15.0   68.0         Spot
# 2489  28DEC10 - 1H 15  sell    15.0   64.0         Spot
# 2490  28DEC10 - 1H 21  sell    15.0   66.0         Spot
#
# 0    Creation timestamp (GMT)                Date Time
# 1         2010-01-02 10:22:43 2010-01-02 18:00:00   18
# 2         2010-01-02 10:22:46 2010-01-02 19:00:00   19
# 3         2010-01-02 12:21:52 2010-01-02 20:00:00   20
# 4         2010-01-02 10:21:36 2010-01-02 21:00:00   21
# 5         2010-01-02 10:21:39 2010-01-02 22:00:00   22
# ...                       ...                 ...  ...
# 2486      2010-12-28 13:48:43 2010-12-28 20:00:00   20
# 2487      2010-12-28 09:03:44 2010-12-28 12:00:00   12
# 2488      2010-12-28 09:03:46 2010-12-28 13:00:00   13
# 2489      2010-12-28 09:03:49 2010-12-28 14:00:00   14
# 2490      2010-12-28 13:48:43 2010-12-28 20:00:00   20
#
# [2490 rows x 8 columns]
#
# ...
#
# Year: 2010
#
# Price: 63225 Euro
# Volume: 27857 MWh
# 0      Instrumentcode  Side  Volume  Price Contracttype  \
# 1     01JAN11 - 1H 15  sell    10.0   31.0         Spot
# 0       Instrumentcode  Side  Volume  Price Contracttype  \
# 1      01JAN13 - 1H 01   buy    15.0   20.0         Spot
# 2      01JAN13 - 1H 02   buy    15.0   20.0         Spot
# 3      01JAN13 - 1H 03   buy    15.0   20.0         Spot
# 4      01JAN13 - 1H 01  sell    10.0   20.0         Spot
# 5      01JAN13 - 1H 01  sell    15.0   20.0         Spot
# ...                ...   ...     ...    ...          ...
# 43196  31DEC13 - 1H 24   buy     1.0   35.0         Spot
# 43197  31DEC13 - 1H 24   buy     5.0   30.0         Spot
# 43198  31DEC13 - 1H 24   buy     5.0   30.0         Spot
# 43199  31DEC13 - 1H 24   buy    15.0   34.0         Spot
# 43200  31DEC13 - 1H 24   buy    45.0   30.0         Spot
#
# 0     Creation timestamp (GMT)                Date Time
# 1          2012-12-31 19:51:44 2013-01-01 00:00:00    0
# 2          2012-12-31 19:51:44 2013-01-01 01:00:00    1
# 3          2012-12-31 19:51:44 2013-01-01 02:00:00    2
# 4          2012-12-31 19:51:44 2013-01-01 00:00:00    0
# 5          2012-12-31 19:51:44 2013-01-01 00:00:00    0
# ...                        ...                 ...  ...
# 43196      2013-12-31 20:22:35 2013-12-31 23:00:00   23
# 43197      2013-12-31 17:42:25 2013-12-31 23:00:00   23
# 43198      2013-12-31 18:32:25 2013-12-31 23:00:00   23
# 43199      2013-12-31 19:02:15 2013-12-31 23:00:00   23
# 43200      2013-12-31 19:12:25 2013-12-31 23:00:00   23
#
# [43200 rows x 8 columns]
#
# ...
#
# Year: 2013
#
# Price: 1138585 Euro
# Volume: 723901 MWh
# 0       Instrumentcode  Side  Volume  Price Contracttype  \
# 1      01JAN14 - 1H 04   buy    30.0   23.0         Spot
# 2      01JAN14 - 1H 04  sell    30.0   23.0         Spot
# 3      01JAN14 - 1H 01   buy    30.0   29.0         Spot
# 4      01JAN14 - 1H 01  sell    30.0   29.0         Spot
# 5      01JAN14 - 1H 02   buy    23.0   28.3         Spot
# ...                ...   ...     ...    ...          ...
# 68794  31DEC14 - 1H 12  sell    15.0   49.0         Spot
# 68795  31DEC14 - 1H 13  sell    21.0   48.0         Spot
# 68796  31DEC14 - 1H 14  sell    25.0   46.0         Spot
# 68797  31DEC14 - 1H 23  sell     5.0   30.0         Spot
# 68798  31DEC14 - 1H 24  sell    12.0   25.0         Spot
#
# 0     Creation timestamp (GMT)                Date Time
# 1          2013-12-31 20:42:45 2014-01-01 03:00:00    3
# 2          2013-12-31 20:42:45 2014-01-01 03:00:00    3
# 3          2013-12-31 20:42:45 2014-01-01 00:00:00    0
# 4          2013-12-31 20:42:45 2014-01-01 00:00:00    0
# 5          2013-12-31 20:42:47 2014-01-01 01:00:00    1
# ...                        ...                 ...  ...
# 68794      2014-12-31 09:22:25 2014-12-31 11:00:00   11
# 68795      2014-12-31 11:02:21 2014-12-31 12:00:00   12
# 68796      2014-12-31 11:42:28 2014-12-31 13:00:00   13
# 68797      2014-12-31 20:42:34 2014-12-31 22:00:00   22
# 68798      2014-12-31 20:42:34 2014-12-31 23:00:00   23
#
# [68788 rows x 8 columns]
#
# ...
#
# Year: 2014
#
# Price: 1446286 Euro
# Volume: 1019772 MWh
# 0             Instrumentcode  Side  Price  Volume Contracttype  \
# 1            01JAN15 - 1H 01   buy   25.0     1.0         Spot
# 2            01JAN15 - 1H 01  sell   25.0     1.0         Spot
# 3            01JAN15 - 1H 01   buy   24.4     5.0         Spot
# 4            01JAN15 - 1H 01  sell   24.4     5.0         Spot
# 5            01JAN15 - 1H 01   buy   28.0     4.0         Spot
# ...                      ...   ...    ...     ...          ...
# 83352  NL ID 15DEC31 - 1H-22  sell   40.0     2.0         Spot
# 83353  NL ID 15DEC31 - 1H-23   buy   40.0     2.0         Spot
# 83354  NL ID 15DEC31 - 1H-23  sell   40.0     2.0         Spot
# 83355  NL ID 15DEC31 - 1H-22   buy   26.0    20.0         Spot
# 83356  NL ID 15DEC31 - 1H-22  sell   26.0    20.0         Spot
#
# 0        Creation timestamp (GMT)                Date Time
# 1      2014-12-31 20:43:24.081000 2015-01-01 00:00:00    0
# 2      2014-12-31 20:43:24.081000 2015-01-01 00:00:00    0
# 3      2014-12-31 20:43:24.098000 2015-01-01 00:00:00    0
# 4      2014-12-31 20:43:24.098000 2015-01-01 00:00:00    0
# 5      2014-12-31 20:43:24.127000 2015-01-01 00:00:00    0
# ...                           ...                 ...  ...
# 83352  2015-12-31 18:10:38.522000 2015-12-31 21:00:00   21
# 83353  2015-12-31 18:10:38.522000 2015-12-31 22:00:00   22
# 83354  2015-12-31 18:10:38.522000 2015-12-31 22:00:00   22
# 83355  2015-12-31 18:35:58.237000 2015-12-31 21:00:00   21
# 83356  2015-12-31 18:35:58.237000 2015-12-31 21:00:00   21
#
# [83346 rows x 8 columns]
#
# ...
#
# Year: 2015
#
# Price: 1787837 Euro
# Volume: 948545 MWh
# 0              Instrumentcode  Side  Price  Volume Contracttype  \
# 1       NL ID 16JAN01 - 1H-02   buy    6.0     4.0         Spot
# 2       NL ID 16JAN01 - 1H-02  sell    6.0     4.0  CrossBorder
# 3       NL ID 16JAN01 - 1H-03   buy    6.0     4.0         Spot
# 4       NL ID 16JAN01 - 1H-03  sell    6.0     4.0  CrossBorder
# 5       NL ID 16JAN01 - 1H-04   buy   40.0     4.0  CrossBorder
# ...                       ...   ...    ...     ...          ...
# 114142  NL ID 16DEC31 - 1H-23  sell   35.0     1.9         Spot
# 114143  NL ID 16DEC31 - 1H-21   buy   48.0     2.0         Spot
# 114144  NL ID 16DEC31 - 1H-21  sell   48.0     2.0         Spot
# 114145  NL ID 16DEC31 - 1H-24   buy   47.0    50.0         Spot
# 114146  NL ID 16DEC31 - 1H-24  sell   47.0    50.0         Spot
#
# 0         Creation timestamp (GMT)                Date Time
# 1       2015-12-31 22:18:29.314000 2016-01-01 01:00:00    1
# 2       2015-12-31 22:18:29.314000 2016-01-01 01:00:00    1
# 3       2015-12-31 22:18:34.322000 2016-01-01 02:00:00    2
# 4       2015-12-31 22:18:34.322000 2016-01-01 02:00:00    2
# 5       2016-01-01 00:02:51.369000 2016-01-01 03:00:00    3
#
# 0      Creation timestamp (GMT)                Date Time
# 1           2017-12-31 20:00:00 2018-01-01 11:00:00   11
# 2           2017-12-31 20:00:00 2018-01-01 11:00:00   11
# 3           2017-12-31 20:00:00 2018-01-01 12:00:00   12
# 4           2017-12-31 20:00:00 2018-01-01 12:00:00   12
# 5           2017-12-31 20:00:00 2018-01-01 13:00:00   13
# ...                         ...                 ...  ...
# 817032      2018-12-31 20:51:59 2018-12-31 23:00:00   23
# 817033      2018-12-31 20:54:23 2018-12-31 22:00:00   22
# 817034      2018-12-31 20:54:23 2018-12-31 22:00:00   22
# 817035      2018-12-31 21:09:18 2018-12-31 23:00:00   23
# 817036      2018-12-31 21:09:18 2018-12-31 23:00:00   23
#
# [817024 rows x 8 columns]
#
# ...
#
# Year: 2018
#
# Price: 22962765 Euro
# Volume: 3421322 MWh
# 0              Instrumentcode  Side  Price  Volume Contracttype  \
# 1       NL ID 19JAN01 - 1H-01   buy   78.0    10.0         Spot
# 2       NL ID 19JAN01 - 1H-01  sell   78.0    10.0         Spot
# 3       NL ID 19JAN01 - 1H-01   buy   60.0     2.0         Spot
# 4       NL ID 19JAN01 - 1H-01  sell   60.0     2.0         Spot
# 5       NL ID 19JAN01 - 1H-01   buy   78.0    25.0         Spot
# ...                       ...   ...    ...     ...          ...
# 183192  NL ID 19NOV28 - 1H-03  sell   45.0     5.0         Spot
# 183193  NL ID 19NOV28 - 1H-03   buy   45.0     5.0         Spot
# 183194  NL ID 19NOV28 - 1H-03  sell   45.0     5.0         Spot
# 183195  NL ID 19NOV28 - 1H-02   buy   42.0     4.0         Spot
# 183196  NL ID 19NOV28 - 1H-02  sell   42.0     4.0         Spot
#
# 0      Creation timestamp (GMT)                Date Time
# 1           31-12-2018 16:47:42 2019-01-01 00:00:00    0
# 2           31-12-2018 16:47:42 2019-01-01 00:00:00    0
# 3           31-12-2018 16:56:41 2019-01-01 00:00:00    0
# 4           31-12-2018 16:56:41 2019-01-01 00:00:00    0
# 5           31-12-2018 16:58:34 2019-01-01 00:00:00    0
# ...                         ...                 ...  ...
# 183192      27-11-2019 22:53:33 2019-11-28 02:00:00    2
# 183193      27-11-2019 22:53:34 2019-11-28 02:00:00    2
# 183194      27-11-2019 22:53:34 2019-11-28 02:00:00    2
# 183195      27-11-2019 22:55:29 2019-11-28 01:00:00    1
# 183196      27-11-2019 22:55:29 2019-11-28 01:00:00    1
#
# [2003370 rows x 8 columns]
#
# ...
#
# Year: 2019
#
# Price: 42260497 Euro
# Volume: 5020633 MWh
#
# ...
#
# Year: 2020
#
# Price: 65371582 Euro
# Volume: 7920701 MWh
#
# ...
#
# Period: 2010–2020
#
# Price (sum): 144825687 Euro
# Volume (sum): 23649951 MWh
#
# ...
#
# Finished successfully
#
# ...

# %% [markdown]
# # Construct ID3

# %%
import datetime

instruments = pd.DataFrame(columns=['ID3'])

instruments['Instrument'] = pd.date_range(f'{years[0]}-01-01 00:00:00', f'{years[-1]}-12-31 23:00:00', freq='h')

    y = filename[24:28]
    if y in years:

        print(colored('...','white'))
        print('')
        print(colored(f'Currently processing file: {filename}', 'blue'))
        print(colored(f'Currently processing year: {y}', 'blue'))
        print('')

        df_da = pd.read_excel(f"./rawDA/{filename}", sheet_name="prices_2")
        for index, row in df_da.iterrows():
            for t in range(1, 25):
                t2 = t - 1
                if t <= 9:
                    t = f'0{t}'
                # df2['Date'] = pd.to_datetime(df2['Date'])
                # print(type(row['PRICES'].strftime("%Y-%m-%d") + ' ' + f'{t}' + ':00:00'))
                # df2 = df2.append(row['PRICES'].strftime("%Y-%m-%d") + ' ' + f'{t}' + ':00:00', row[f'Hour {t}']) 
                date.append(row['PRICES'].strftime("%Y-%m-%d") + ' ' + f'{t2}' + ':00:00')
                mcp.append(row[f'Hour {t}'])
                # df2['MCP'] = df2['MCP'].append(row[f'Hour {t}'])
                # pd.to_datetime(df_group3['Date'], format='(%Y, %m, %d, %H)')
                
                # df2['Date2'] = pd.to_datetime(df2['Date'], format='%Y-%m-%d %H')

                # pd.to_datetime(df_group3['Date'], format='(%Y, %m, %d, %H)')
                
                # df2['Date'] = pd.to_datetime(df2, format='(%Y, %m, %d, %H)')
        
        df_da2 = pd.DataFrame(date)
        df_da2.columns = ['Date']
        df_da2['MCP'] = pd.DataFrame(mcp)
        df_da2 = df_da2.set_index(pd.DatetimeIndex(df_da2['Date']))
        df_da2 = df_da2.drop(['Date'], axis=1)

print(colored('...','white'))
print('')
print(colored(f'(DA) Grouped by hour', 'blue'))
print('')

print(colored('...','white'))
print('')
print(df_da2)
print('')

print(colored('...','white'))
print('')
print(colored(f'Finished successfully', 'green'))
print('')
print(colored('...','white'))
print('')

df_da2.index.names = ['Instrument']

# df_da2['Instrument'] = df_da2.index
# df_da2 = df_da2.reset_index(drop=True)
df_da2.to_pickle(f"./DA.pkl")
# Out:
# ...
#
# Files in directory: ['DAM - Historical data - 2015.xls', 'DAM - Historical data - 2016.xls', 'DAM - Historical data - 2017.xls', 'DAM - Historical data - 2018.xls', 'DAM - Historical data - 2019.xls']
#
# ...
#
# Currently processing file: DAM - Historical data - 2015.xls
# Currently processing year: 2015
#
# ...
#
# Currently processing file: DAM - Historical data - 2016.xls
# Currently processing year: 2016
#
# ...
#
# Currently processing file: DAM - Historical data - 2017.xls
# Currently processing year: 2017
#
# ...
#
# Currently processing file: DAM - Historical data - 2018.xls
# Currently processing year: 2018
#
# ...
#
# Currently processing file: DAM - Historical data - 2019.xls
# Currently processing year: 2019
#
# ...
#
# (DA) Grouped by hour
#
# ...
#
#                        MCP
# Date
# 2015-01-01 00:00:00  38.50
# 2015-01-01 01:00:00  38.22
# 2015-01-01 02:00:00  35.60
# 2015-01-01 03:00:00  33.00
# 2015-01-01 04:00:00  27.41
# ...                    ...
# 2019-12-31 19:00:00  46.00
# 2019-12-31 20:00:00  42.20
# 2019-12-31 21:00:00  39.74
# 2019-12-31 22:00:00  38.88
# 2019-12-31 23:00:00  37.21
#
# [43824 rows x 1 columns]
#
# ...
#
# Finished successfully
#
# ...
